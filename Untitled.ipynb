# %%
import plotly.express as px
from src.config import df, ordered_p25_list, p25_question_map, p25_tag_map
from src.charts.plotly import create_0_to_10_percentage_bar_chart2
from src.config import p32_tag_map, df
import plotly.colors as pc
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Out:
#       elkar  inkes  lurral  tfno  P0A  P0B  P01  P02  P03  P04  ...  p36  p37  \
# 0         1    813       1     1    3   59    2   79    5    3  ...    5    2
# 1         2    606       1     1    3  999    2   71    5    2  ...    5    2
# 2         3     46       1     1    3    2    2   61    2    3  ...    4    3
# 3         4    379       1     1    3   59    2   68    5    4  ...    5    2
# 4         5    813       1     1    3   59    2   24    1    2  ...    1    5
# ...     ...    ...     ...   ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 3025   3026    875       3     2    1   29    1   54    1    2  ...    1    5
# 3026   3027    881       3     2    3   69    2   55    1    3  ...    3    5
# 3027   3028    339       3     2    3    9    2   80    5    3  ...    3    3
# 3028   3029    365       3     1    3  902    2   75    5    2  ...    2    5
# 3029   3030    881       3     1    3   45    1   60    1    5  ...    3    5
#
# ...

# %%
long_df =
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 21
#      11     fig = px.bar(
#      12         df,
#      13         x = "p32",
#    (...)     16
#      17     )
#      19     return fig
# ---> 21 create_0_to_10_percentage_bar_chart(
#      22     df,
#      23     "p32",
#      24     "Nivel de izquierda-derecha",
#      25     "Eje izquierda derecha",
#      26     p32_tag_map,
#      27 )
#
# Cell In[18], line 11, in create_0_to_10_percentage_bar_chart(df, question, chart_title, x_title, tag_map)
#       8 count.index = count.index.map(tag_map)
#       9 count = count.sort_index(ascending=True).reset_index()
# ---> 11 fig = px.bar(
#      12     df,
#      13     x = "p32",
#      14     y = "count",
#      15     title = chart_title,
#      16
#      17 )
#      19 return fig
#
# ...
